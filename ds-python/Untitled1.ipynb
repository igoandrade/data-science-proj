# %% [markdown]
# # Análise de Dados de Acidentes

# %% [markdown]
# ## Bibliotecas importadas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as ns

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
plt.style.use('seaborn')

# %% [markdown]
# ## Carregamento dos dados

# %%
survey_raw_df = pd.read_csv('../data/survey_results_public.csv')

# %%
survey_raw_df.head()
# Out:
#    Respondent                                                MainBranch  \
# 0           1                            I am a developer by profession
# 1           2                            I am a developer by profession
# 2           3                               I code primarily as a hobby
# 3           4                            I am a developer by profession
# 4           5  I used to be a developer by profession, but no longer am
#
#   Hobbyist   Age Age1stCode CompFreq  CompTotal  ConvertedComp  \
# 0      Yes   NaN         13  Monthly        NaN            NaN
# 1       No   NaN         19      NaN        NaN            NaN
# 2      Yes   NaN         15      NaN        NaN            NaN
# 3      Yes  25.0         18      NaN        NaN            NaN
# 4      Yes  31.0         16      NaN        NaN            NaN
#
#               Country    CurrencyDesc  ...                  SurveyEase  \
# 0             Germany   European Euro  ...  Neither easy nor difficult
# ...

# %%
survey_raw_df.shape
# Out:
# (64461, 61)

# %% [markdown]
# O conjunto de dados refere-se a 64.461 observações (linhas) e 61 variáveis (colunas). Destas 61 colunas, a primeira denominada 'Respondent' representa o participande da pesquisa de forma anônima. As 60 demais colunas são questões respondidas pelos participantes da pesquisa.

# %% [markdown]
# Na céculas seguintes, são mostradas as questões para cada uma das 60 colunas descritas acima:

# %%
schema_fname = '../data/survey_results_schema.csv'

# %%
schema_raw = pd.read_csv(schema_fname,index_col='Column')

# %%
schema_raw
# Out:
#                                                                                                                                                                                                                                                                                                                                                                   QuestionText
# Column
# Respondent                                                                                                                                                                                                                                                                                              Randomized respondent ID number (not in order of survey response time)
# ...

# %%
schema_raw.loc['YearsCode']
# Out:
# QuestionText    Including any education, how many years have you been coding in total?
# Name: YearsCode, dtype: object

# %% [markdown]
# ## Preparação e Limpeza dos Dados

# %% [markdown]
# Este projeto se delimita às seguintes áreas:
#  * Propriedades Demográficas dos respondentes e da comunidade global de programação
#  * Distribuição de habilidade de programação, experiências e preferências
#  * Informações de emprego
#
# As seguintes colunas serão selecionadas:

# %%
selected_columns = [
    # Demográficas
    ''
]
